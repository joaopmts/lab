# %%
#exploracao
# Out:
# <style>
# .jp-OutputArea-output pre,
# .jp-RenderedText pre,
# pre {
#   white-space: pre !important;
#   overflow: auto !important;
# }
#
# .jp-OutputArea-output {
#   overflow: auto !important;
#   max-height: 60vh;
# }
# </style>

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
# Out:
# 25/09/26 02:13:55 ERROR TaskSchedulerImpl: Lost executor 0 on 172.18.0.15: worker lost: 172.18.0.15:39361 got disassociated

# %%
spark = SparkSession.builder\
    .appName("Discovery")\
    .master("spark://spark-master:7077")\
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/09/26 02:05:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
path = "discovery/cnpj/dados_abertos_cnpj"

# %%
df = spark.read.format("binaryFile").load(bucket_path)
